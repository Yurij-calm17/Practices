# %% [markdown]
# Характеристика	Public Cloud	Private Cloud
# Власник інфраструктури	Постачальник (AWS, Azure, GCP)	Організація/міністерство оборони
# Безпека	Висока, але залежить від постачальника	Дуже висока – повний контроль над політиками безпеки
# Контроль доступу	Обмежений, частково делегований	Повний контроль
# Масштабованість	Висока (можна швидко збільшити ресурси)	Обмежена локальною інфраструктурою
# Вартість	Нижча на старті, оплата за використання	Висока початкова вартість, але вигідна при тривалому використанні
# Приклади використання	Навчальні середовища, некритичні аналітичні системи	Бойові інформаційні системи, системи управління військами
# ✅ Висновок:
# Для бойових ІАС доцільніше використовувати Private Cloud з міркувань безпеки.
# Для досліджень, тренувань або аналітики – Public Cloud є ефективним і гнучким рішенням.
